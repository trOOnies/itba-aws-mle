# %% [markdown]
# # Step 1 - Training del modelo

# %% [markdown]
# ## Seteos iniciales

# %% [markdown]
# Logueamos sólo los mensajes de warning y error

# %%
import logging

logging.getLogger("sagemaker.config").setLevel(logging.WARNING)
logging.getLogger("sagemaker.experiments.run").setLevel(logging.WARNING)

# %% [markdown]
# Mostramos las versiones de las librerías de Python importantes para el proyecto

# %%
import awscli
import boto3
import numpy
import pandas
import sagemaker

print("sagemaker\t", sagemaker.__version__)
print("pandas\t\t", pandas.__version__)
print("numpy\t\t", numpy.__version__)
print("boto3\t\t", boto3.__version__)
print("awscli\t\t", awscli.__version__)
# Out:
# sagemaker	 2.215.0
# pandas		 2.2.2
# numpy		 1.26.4
# boto3		 1.34.84
# awscli		 1.32.84

# %%
role = sagemaker.get_execution_role()
region = boto3.Session().region_name

sage_session = sagemaker.Session()
bucket_name = sage_session.default_bucket()
prefix = "australia-rain-processed"

print("Region:", region)
print("Rol:", role)
print("Info S3:")
print(f"- Bucket: {bucket_name}")
print(f"- Prefix: {prefix}")
# Out:
# Region: us-east-1
# Rol: arn:aws:iam::335415446667:role/service-role/AmazonSageMakerExecutionRole-sagemaker-stack
# Info S3:
# - Bucket: sagemaker-us-east-1-335415446667
# - Prefix: australia-rain-processed

# %% [markdown]
# Genero un experiment_name que puede guardarse y recuperarse con las funciones especiales de notebook

# %%
import time
experiment_name = f"australia-rain-exp-{time.strftime('%Y-%m-%d-%H-%M-%S', time.localtime())}"
print(f"Experiment name: {experiment_name}")
# Out:
# Experiment name: australia-rain-exp-2024-11-18-18-39-24

# %%
# %store experiment_name
# Out:
# Stored 'experiment_name' (str)

# %% [markdown]
# ## Training

# %%
from sagemaker.xgboost import XGBoost

hyperparameters = {
    "max_depth": "3",
    "eta": "0.1",
    "gamma": "0",
    "min_child_weight": "1",
    "silent": "0",
    "objective": "binary:logistic",
    "num_round": "10",
    "eval_metric": "auc"
}

base_job_name = f"{prefix}-sm-xgb"
entry_point   = "training.py"
source_dir    = "scripts/training/"
output_path   = f"s3://{bucket_name}/{prefix}/output/"
code_location = f"s3://{bucket_name}/{prefix}/code"

estimator = XGBoost(
    base_job_name=base_job_name,
    entry_point=entry_point,
    source_dir=source_dir,
    output_path=output_path,
    code_location=code_location,
    hyperparameters=hyperparameters,
    instance_type="ml.m5.xlarge",
    instance_count=1,
    framework_version="0.90-2",
    py_version="py3",
    role=role,
)

# %%
from sagemaker.experiments.run import Run
import time

time_str = time.strftime("%H-%M-%S", time.localtime())

run_name            = f"training-{time_str}"
run_display_name    = "xgboost-training"
databrew_train_fd   = "australia-rain-train-dbjob_18Nov2024_1731954734584"
databrew_val_fd     = "australia-rain-val-dbjob_18Nov2024_1731954770752"

train_config = sagemaker.TrainingInput(
    f"s3://{bucket_name}/{prefix}/{databrew_train_fd}/",
    content_type="text/csv",
)
val_config = sagemaker.TrainingInput(
    f"s3://{bucket_name}/{prefix}/{databrew_val_fd}/",
    content_type="text/csv",
)

print("Run name:", run_name)
# Out:
# Run name: training-19-29-11

# %%
with Run(
    experiment_name=experiment_name,
    run_name=run_name,
    run_display_name=run_display_name,
    sagemaker_session=sage_session,
) as run:
    estimator.fit(
        {
            "train": train_config,
            "validation": val_config,
        }
    )
# Out:
# INFO:sagemaker:Creating training-job with name: australia-rain-processed-sm-xgb-2024-11-18-19-29-13-266
# 2024-11-18 19:29:13 Starting - Starting the training job...
# 2024-11-18 19:29:30 Starting - Preparing the instances for training...
# 2024-11-18 19:29:51 Downloading - Downloading input data...
# 2024-11-18 19:30:16 Downloading - Downloading the training image...
# 2024-11-18 19:31:08 Training - Training image download completed. Training in progress.
# 2024-11-18 19:31:08 Uploading - Uploading generated training modelINFO:sagemaker-containers:Imported framework sagemaker_xgboost_container.training
# INFO:sagemaker-containers:No GPUs detected (normal if no gpus installed)
# INFO:sagemaker_xgboost_container.training:Invoking user training script.
# INFO:sagemaker-containers:Module training does not provide a setup.py.
# Generating setup.py
# INFO:sagemaker-containers:Generating setup.cfg
# INFO:sagemaker-containers:Generating MANIFEST.in
# INFO:sagemaker-containers:Installing module with the following command:
# /miniconda3/bin/python3 -m pip install .
# Processing /opt/ml/code
# Building wheels for collected packages: training
#   Building wheel for training (setup.py): started
#   Building wheel for training (setup.py): finished with status 'done'
#   Created wheel for training: filename=training-1.0.0-py2.py3-none-any.whl size=5941 sha256=0e82650bc92332c93968f1acf6873f4149d2f39e969c2a991db81cf89dca2a9a
#   Stored in directory: /home/model-server/tmp/pip-ephem-wheel-cache-t7jg_ieb/wheels/95/c1/85/65aaf48b35aba88c6e896d2fd04a4b69f1cee0d81ea32993ca
# Successfully built training
# Installing collected packages: training
# Successfully installed training-1.0.0
# INFO:sagemaker-containers:No GPUs detected (normal if no gpus installed)
# INFO:sagemaker-containers:Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "train": "/opt/ml/input/data/train",
#         "validation": "/opt/ml/input/data/validation"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_xgboost_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "eta": "0.1",
#         "eval_metric": "auc",
#         "gamma": "0",
#         "max_depth": "3",
#         "min_child_weight": "1",
#         "num_round": "10",
#         "objective": "binary:logistic",
#         "silent": "0"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "train": {
#             "ContentType": "text/csv",
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "validation": {
#             "ContentType": "text/csv",
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "australia-rain-processed-sm-xgb-2024-11-18-19-29-13-266",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-335415446667/australia-rain-processed/code/australia-rain-processed-sm-xgb-2024-11-18-19-29-13-266/source/sourcedir.tar.gz",
#     "module_name": "training",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "current_instance_type": "ml.m5.xlarge",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.m5.xlarge",
#                 "hosts": [
#                     "algo-1"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "training.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"eta":"0.1","eval_metric":"auc","gamma":"0","max_depth":"3","min_child_weight":"1","num_round":"10","objective":"binary:logistic","silent":"0"}
# SM_USER_ENTRY_POINT=training.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.m5.xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.xlarge"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"train":{"ContentType":"text/csv","RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"ContentType":"text/csv","RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["train","validation"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=training
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_xgboost_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-335415446667/australia-rain-processed/code/australia-rain-processed-sm-xgb-2024-11-18-19-29-13-266/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train","validation":"/opt/ml/input/data/validation"},"current_host":"algo-1","framework_module":"sagemaker_xgboost_container.training:main","hosts":["algo-1"],"hyperparameters":{"eta":"0.1","eval_metric":"auc","gamma":"0","max_depth":"3","min_child_weight":"1","num_round":"10","objective":"binary:logistic","silent":"0"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"ContentType":"text/csv","RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"ContentType":"text/csv","RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"australia-rain-processed-sm-xgb-2024-11-18-19-29-13-266","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-335415446667/australia-rain-processed/code/australia-rain-processed-sm-xgb-2024-11-18-19-29-13-266/source/sourcedir.tar.gz","module_name":"training","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.m5.xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.xlarge"}],"network_interface_name":"eth0"},"user_entry_point":"training.py"}
# SM_USER_ARGS=["--eta","0.1","--eval_metric","auc","--gamma","0","--max_depth","3","--min_child_weight","1","--num_round","10","--objective","binary:logistic","--silent","0"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_CHANNEL_VALIDATION=/opt/ml/input/data/validation
# SM_HP_ETA=0.1
# SM_HP_EVAL_METRIC=auc
# SM_HP_GAMMA=0
# SM_HP_MAX_DEPTH=3
# SM_HP_MIN_CHILD_WEIGHT=1
# SM_HP_NUM_ROUND=10
# SM_HP_OBJECTIVE=binary:logistic
# SM_HP_SILENT=0
# PYTHONPATH=/miniconda3/bin:/:/miniconda3/lib/python3.6/site-packages/xgboost/dmlc-core/tracker:/miniconda3/lib/python36.zip:/miniconda3/lib/python3.6:/miniconda3/lib/python3.6/lib-dynload:/miniconda3/lib/python3.6/site-packages
# Invoking script with the following command:
# /miniconda3/bin/python3 -m training --eta 0.1 --eval_metric auc --gamma 0 --max_depth 3 --min_child_weight 1 --num_round 10 --objective binary:logistic --silent 0
# Train contents:
# ['australia-rain-train-dbjob_18Nov2024_1731954734584_part00000.csv']
# Val contents:
# ['australia-rain-val-dbjob_18Nov2024_1731954770752_part00000.csv']
# Loading train dataframe...
# Loading val dataframe...
# Train features shape: (108509, 19)
# Train labels shape:   (108509,)
# Val features shape:   (13551, 19)
# Val labels shape:     (13551,)
# [0]#011train-auc:0.802526#011val-auc:0.797603
# [1]#011train-auc:0.816571#011val-auc:0.812566
# [2]#011train-auc:0.829371#011val-auc:0.825602
# [3]#011train-auc:0.832058#011val-auc:0.828603
# [4]#011train-auc:0.836056#011val-auc:0.833402
# [5]#011train-auc:0.836425#011val-auc:0.833741
# [6]#011train-auc:0.838322#011val-auc:0.835184
# [7]#011train-auc:0.839649#011val-auc:0.836264
# [8]#011train-auc:0.840766#011val-auc:0.837715
# [9]#011train-auc:0.841825#011val-auc:0.838947
#
# 2024-11-18 19:31:21 Completed - Training job completed
# Training seconds: 90
# Billable seconds: 90

# %% [markdown]
# ### Tuneo de hipérparametros

# %%
from sagemaker.parameter import ContinuousParameter, IntegerParameter
from sagemaker.tuner import HyperparameterTuner

hyperparameter_ranges = {
    "max_depth": IntegerParameter(3, 10),        # base: "3"
    "eta": ContinuousParameter(0.01, 0.30),      # base: "0.1"
    "gamma": ContinuousParameter(0.00, 0.50),    # base: "0"
    "min_child_weight": IntegerParameter(1, 6),  # base: "1"
}
hyperparameters_to_keep_static = {
    "silent": "0",
    "objective": "binary:logistic",
    "num_round": "10",
    "eval_metric": "auc"
}

# %%
tuner = HyperparameterTuner(
    estimator=estimator,
    objective_metric_name="validation:auc",
    hyperparameter_ranges=hyperparameter_ranges,
    hyperparameters_to_keep_static=hyperparameters_to_keep_static,
    max_jobs=20,
    max_parallel_jobs=3,
    autotune=True,
)

# %%
from sagemaker.experiments.run import Run
import time

time_str = time.strftime("%H-%M-%S", time.localtime())

run_name         = f"hpo-{time_str}"
run_display_name = "xgboost-hpo"

print("Run name:", run_name)
# Out:
# Run name: hpo-20-43-32

# %%
with Run(
    experiment_name=experiment_name,
    run_name=run_name,
    run_display_name=run_display_name,
    sagemaker_session=sage_session,
) as run:
    tuner.fit(
        {
            "train": train_config,
            "validation": val_config,
        }
    )
# Out:
# INFO:sagemaker:Creating hyperparameter tuning job with name: sagemaker-xgboost-241118-2043
# ................................................................................................!

# %% [markdown]
# ## Experimentos corridos

# %%
from sagemaker.analytics import ExperimentAnalytics

analytics = ExperimentAnalytics(experiment_name=experiment_name)
df_analytics = analytics.dataframe()

df_analytics
# Out:
#                                    TrialComponentName  \
# 0   australia-rain-exp-2024-11-18-18-39-24-hpo-20-...
# 1   australia-rain-exp-2024-11-18-18-39-24-hpo-20-...
# 2   australia-rain-exp-2024-11-18-18-39-24-hpo-20-...
# 3   australia-rain-exp-2024-11-18-18-39-24-hpo-20-...
# 4   australia-rain-exp-2024-11-18-18-39-24-hpo-20-...
# 5   australia-rain-exp-2024-11-18-18-39-24-hpo-20-...
# 6   australia-rain-exp-2024-11-18-18-39-24-hpo-20-...
# 7   australia-rain-exp-2024-11-18-18-39-24-hpo-19-...
# 8   australia-rain-exp-2024-11-18-18-39-24-hpo-19-...
# 9   australia-rain-exp-2024-11-18-18-39-24-trainin...
# 10  australia-rain-processed-sm-xgb-2024-11-18-19-...
# 11  australia-rain-processed-sm-xgb-2024-11-18-19-...
# 12  australia-rain-exp-2024-11-18-18-39-24-trainin...
# 13  australia-rain-processed-sm-xgb-2024-11-18-19-...
# 14  australia-rain-exp-2024-11-18-18-39-24-trainin...
# 15  australia-rain-processed-sm-xgb-2024-11-18-18-...
# 16  australia-rain-exp-2024-11-18-18-39-24-trainin...
#
#                                           DisplayName  \
# 0                                         xgboost-hpo
# 1                                         xgboost-hpo
# 2                                         xgboost-hpo
# 3                                         xgboost-hpo
# 4                                         xgboost-hpo
# 5                                         xgboost-hpo
# 6                                         xgboost-hpo
# 7                                         xgboost-hpo
# 8                                         xgboost-hpo
# 9                                    xgboost-training
# 10  australia-rain-processed-sm-xgb-2024-11-18-19-...
# 11  australia-rain-processed-sm-xgb-2024-11-18-19-...
# 12                                   xgboost-training
# 13  australia-rain-processed-sm-xgb-2024-11-18-19-...
# 14                                   xgboost-training
# 15  australia-rain-processed-sm-xgb-2024-11-18-18-...
# 16                                   xgboost-training
#
#                                                Trials  \
# 0   [Default-Run-Group-australia-rain-exp-2024-11-...
# 1   [Default-Run-Group-australia-rain-exp-2024-11-...
# 2   [Default-Run-Group-australia-rain-exp-2024-11-...
# 3   [Default-Run-Group-australia-rain-exp-2024-11-...
# 4   [Default-Run-Group-australia-rain-exp-2024-11-...
# 5   [Default-Run-Group-australia-rain-exp-2024-11-...
# 6   [Default-Run-Group-australia-rain-exp-2024-11-...
# 7   [Default-Run-Group-australia-rain-exp-2024-11-...
# 8   [Default-Run-Group-australia-rain-exp-2024-11-...
# 9   [Default-Run-Group-australia-rain-exp-2024-11-...
# 10  [Default-Run-Group-australia-rain-exp-2024-11-...
# 11  [Default-Run-Group-australia-rain-exp-2024-11-...
# 12  [Default-Run-Group-australia-rain-exp-2024-11-...
# 13  [Default-Run-Group-australia-rain-exp-2024-11-...
# 14  [Default-Run-Group-australia-rain-exp-2024-11-...
# 15  [Default-Run-Group-australia-rain-exp-2024-11-...
# 16  [Default-Run-Group-australia-rain-exp-2024-11-...
#
#                                  Experiments  \
# 0   [australia-rain-exp-2024-11-18-18-39-24]
# 1   [australia-rain-exp-2024-11-18-18-39-24]
# 2   [australia-rain-exp-2024-11-18-18-39-24]
# 3   [australia-rain-exp-2024-11-18-18-39-24]
# 4   [australia-rain-exp-2024-11-18-18-39-24]
# 5   [australia-rain-exp-2024-11-18-18-39-24]
# 6   [australia-rain-exp-2024-11-18-18-39-24]
# 7   [australia-rain-exp-2024-11-18-18-39-24]
# 8   [australia-rain-exp-2024-11-18-18-39-24]
# 9   [australia-rain-exp-2024-11-18-18-39-24]
# 10  [australia-rain-exp-2024-11-18-18-39-24]
# 11  [australia-rain-exp-2024-11-18-18-39-24]
# 12  [australia-rain-exp-2024-11-18-18-39-24]
# 13  [australia-rain-exp-2024-11-18-18-39-24]
# 14  [australia-rain-exp-2024-11-18-18-39-24]
# 15  [australia-rain-exp-2024-11-18-18-39-24]
# 16  [australia-rain-exp-2024-11-18-18-39-24]
#
#                                             SourceArn  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  arn:aws:sagemaker:us-east-1:335415446667:train...
# 11  arn:aws:sagemaker:us-east-1:335415446667:train...
# 12                                                NaN
# 13  arn:aws:sagemaker:us-east-1:335415446667:train...
# 14                                                NaN
# 15  arn:aws:sagemaker:us-east-1:335415446667:train...
# 16                                                NaN
#
#                                    SageMaker.ImageUri  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  683313688378.dkr.ecr.us-east-1.amazonaws.com/s...
# 11  683313688378.dkr.ecr.us-east-1.amazonaws.com/s...
# 12                                                NaN
# 13  683313688378.dkr.ecr.us-east-1.amazonaws.com/s...
# 14                                                NaN
# 15  683313688378.dkr.ecr.us-east-1.amazonaws.com/s...
# 16                                                NaN
#
#     SageMaker.InstanceCount SageMaker.InstanceType  SageMaker.VolumeSizeInGB  \
# 0                       NaN                    NaN                       NaN
# 1                       NaN                    NaN                       NaN
# 2                       NaN                    NaN                       NaN
# 3                       NaN                    NaN                       NaN
# 4                       NaN                    NaN                       NaN
# 5                       NaN                    NaN                       NaN
# 6                       NaN                    NaN                       NaN
# 7                       NaN                    NaN                       NaN
# 8                       NaN                    NaN                       NaN
# 9                       NaN                    NaN                       NaN
# 10                      1.0           ml.m5.xlarge                      30.0
# 11                      1.0           ml.m5.xlarge                      30.0
# 12                      NaN                    NaN                       NaN
# 13                      1.0           ml.m5.xlarge                      30.0
# 14                      NaN                    NaN                       NaN
# 15                      1.0           ml.m5.xlarge                      30.0
# 16                      NaN                    NaN                       NaN
#
#       eta  ... train - MediaType  \
# 0     NaN  ...               NaN
# 1     NaN  ...               NaN
# 2     NaN  ...               NaN
# 3     NaN  ...               NaN
# 4     NaN  ...               NaN
# 5     NaN  ...               NaN
# 6     NaN  ...               NaN
# 7     NaN  ...               NaN
# 8     NaN  ...               NaN
# 9     NaN  ...               NaN
# 10  "0.1"  ...          text/csv
# 11  "0.1"  ...          text/csv
# 12    NaN  ...               NaN
# 13  "0.1"  ...          text/csv
# 14    NaN  ...               NaN
# 15  "0.1"  ...          text/csv
# 16    NaN  ...               NaN
#
#                                         train - Value validation - MediaType  \
# 0                                                 NaN                    NaN
# 1                                                 NaN                    NaN
# 2                                                 NaN                    NaN
# 3                                                 NaN                    NaN
# 4                                                 NaN                    NaN
# 5                                                 NaN                    NaN
# 6                                                 NaN                    NaN
# 7                                                 NaN                    NaN
# 8                                                 NaN                    NaN
# 9                                                 NaN                    NaN
# 10  s3://sagemaker-us-east-1-335415446667/australi...               text/csv
# 11  s3://sagemaker-us-east-1-335415446667/australi...                    NaN
# 12                                                NaN                    NaN
# 13  s3://sagemaker-us-east-1-335415446667/australi...                    NaN
# 14                                                NaN                    NaN
# 15  s3://sagemaker-us-east-1-335415446667/australi...               text/csv
# 16                                                NaN                    NaN
#
#                                    validation - Value  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  s3://sagemaker-us-east-1-335415446667/australi...
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  s3://sagemaker-us-east-1-335415446667/australi...
# 16                                                NaN
#
#    SageMaker.DebugHookOutput - MediaType  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# 5                                    NaN
# 6                                    NaN
# 7                                    NaN
# 8                                    NaN
# 9                                    NaN
# 10                                   NaN
# 11                                   NaN
# 12                                   NaN
# 13                                   NaN
# 14                                   NaN
# 15                                   NaN
# 16                                   NaN
#
#                     SageMaker.DebugHookOutput - Value  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  s3://sagemaker-us-east-1-335415446667/australi...
# 11  s3://sagemaker-us-east-1-335415446667/australi...
# 12                                                NaN
# 13  s3://sagemaker-us-east-1-335415446667/australi...
# 14                                                NaN
# 15  s3://sagemaker-us-east-1-335415446667/australi...
# 16                                                NaN
#
#     SageMaker.ModelArtifact - MediaType  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN
# 6                                   NaN
# 7                                   NaN
# 8                                   NaN
# 9                                   NaN
# 10                                  NaN
# 11                                  NaN
# 12                                  NaN
# 13                                  NaN
# 14                                  NaN
# 15                                  NaN
# 16                                  NaN
#
#                       SageMaker.ModelArtifact - Value val - MediaType  \
# 0                                                 NaN             NaN
# 1                                                 NaN             NaN
# 2                                                 NaN             NaN
# 3                                                 NaN             NaN
# 4                                                 NaN             NaN
# 5                                                 NaN             NaN
# 6                                                 NaN             NaN
# 7                                                 NaN             NaN
# 8                                                 NaN             NaN
# 9                                                 NaN             NaN
# 10  s3://sagemaker-us-east-1-335415446667/australi...             NaN
# 11  s3://sagemaker-us-east-1-335415446667/australi...        text/csv
# 12                                                NaN             NaN
# 13  s3://sagemaker-us-east-1-335415446667/australi...        text/csv
# 14                                                NaN             NaN
# 15  s3://sagemaker-us-east-1-335415446667/australi...             NaN
# 16                                                NaN             NaN
#
#                                           val - Value
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  s3://sagemaker-us-east-1-335415446667/australi...
# 12                                                NaN
# 13  s3://sagemaker-us-east-1-335415446667/australi...
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
#
# [17 rows x 38 columns]

# %%
df_analytics.dtypes
# Out:
# TrialComponentName                        object
# DisplayName                               object
# Trials                                    object
# Experiments                               object
# SourceArn                                 object
# SageMaker.ImageUri                        object
# SageMaker.InstanceCount                  float64
# SageMaker.InstanceType                    object
# SageMaker.VolumeSizeInGB                 float64
# eta                                       object
# eval_metric                               object
# gamma                                     object
# max_depth                                 object
# min_child_weight                          object
# num_round                                 object
# objective                                 object
# sagemaker_container_log_level            float64
# sagemaker_job_name                        object
# sagemaker_program                         object
# sagemaker_region                          object
# sagemaker_submit_directory                object
# silent                                    object
# train:auc - Min                          float64
# train:auc - Max                          float64
# train:auc - Avg                          float64
# train:auc - StdDev                       float64
# train:auc - Last                         float64
# train:auc - Count                        float64
# train - MediaType                         object
# train - Value                             object
# validation - MediaType                    object
# validation - Value                        object
# SageMaker.DebugHookOutput - MediaType    float64
# SageMaker.DebugHookOutput - Value         object
# SageMaker.ModelArtifact - MediaType      float64
# SageMaker.ModelArtifact - Value           object
# val - MediaType                           object
# val - Value                               object
# dtype: object

# %%
df_analytics.iloc[0]
# Out:
# TrialComponentName                       australia-rain-exp-2024-11-18-18-39-24-hpo-20-...
# DisplayName                                                                    xgboost-hpo
# Trials                                   [Default-Run-Group-australia-rain-exp-2024-11-...
# Experiments                                       [australia-rain-exp-2024-11-18-18-39-24]
# SourceArn                                                                              NaN
# SageMaker.ImageUri                                                                     NaN
# SageMaker.InstanceCount                                                                NaN
# SageMaker.InstanceType                                                                 NaN
# SageMaker.VolumeSizeInGB                                                               NaN
# eta                                                                                    NaN
# eval_metric                                                                            NaN
# gamma                                                                                  NaN
# max_depth                                                                              NaN
# min_child_weight                                                                       NaN
# num_round                                                                              NaN
# objective                                                                              NaN
# sagemaker_container_log_level                                                          NaN
# sagemaker_job_name                                                                     NaN
# sagemaker_program                                                                      NaN
# sagemaker_region                                                                       NaN
# sagemaker_submit_directory                                                             NaN
# silent                                                                                 NaN
# train:auc - Min                                                                        NaN
# train:auc - Max                                                                        NaN
# train:auc - Avg                                                                        NaN
# train:auc - StdDev                                                                     NaN
# train:auc - Last                                                                       NaN
# train:auc - Count                                                                      NaN
# train - MediaType                                                                      NaN
# train - Value                                                                          NaN
# validation - MediaType                                                                 NaN
# validation - Value                                                                     NaN
# SageMaker.DebugHookOutput - MediaType                                                  NaN
# SageMaker.DebugHookOutput - Value                                                      NaN
# SageMaker.ModelArtifact - MediaType                                                    NaN
# SageMaker.ModelArtifact - Value                                                        NaN
# val - MediaType                                                                        NaN
# val - Value                                                                            NaN
# Name: 0, dtype: object

# %%
df_analytics[["TrialComponentName", "Experiments", "DisplayName"] + [c for c in df_analytics if c.startswith(("train:auc", "val"))]]
# Out:
#                                    TrialComponentName  \
# 0   australia-rain-exp-2024-11-18-18-39-24-hpo-20-...
# 1   australia-rain-exp-2024-11-18-18-39-24-hpo-20-...
# 2   australia-rain-exp-2024-11-18-18-39-24-hpo-20-...
# 3   australia-rain-exp-2024-11-18-18-39-24-hpo-20-...
# 4   australia-rain-exp-2024-11-18-18-39-24-hpo-20-...
# 5   australia-rain-exp-2024-11-18-18-39-24-hpo-20-...
# 6   australia-rain-exp-2024-11-18-18-39-24-hpo-20-...
# 7   australia-rain-exp-2024-11-18-18-39-24-hpo-19-...
# 8   australia-rain-exp-2024-11-18-18-39-24-hpo-19-...
# 9   australia-rain-exp-2024-11-18-18-39-24-trainin...
# 10  australia-rain-processed-sm-xgb-2024-11-18-19-...
# 11  australia-rain-processed-sm-xgb-2024-11-18-19-...
# 12  australia-rain-exp-2024-11-18-18-39-24-trainin...
# 13  australia-rain-processed-sm-xgb-2024-11-18-19-...
# 14  australia-rain-exp-2024-11-18-18-39-24-trainin...
# 15  australia-rain-processed-sm-xgb-2024-11-18-18-...
# 16  australia-rain-exp-2024-11-18-18-39-24-trainin...
#
#                                  Experiments  \
# 0   [australia-rain-exp-2024-11-18-18-39-24]
# 1   [australia-rain-exp-2024-11-18-18-39-24]
# 2   [australia-rain-exp-2024-11-18-18-39-24]
# 3   [australia-rain-exp-2024-11-18-18-39-24]
# 4   [australia-rain-exp-2024-11-18-18-39-24]
# 5   [australia-rain-exp-2024-11-18-18-39-24]
# 6   [australia-rain-exp-2024-11-18-18-39-24]
# 7   [australia-rain-exp-2024-11-18-18-39-24]
# 8   [australia-rain-exp-2024-11-18-18-39-24]
# 9   [australia-rain-exp-2024-11-18-18-39-24]
# 10  [australia-rain-exp-2024-11-18-18-39-24]
# 11  [australia-rain-exp-2024-11-18-18-39-24]
# 12  [australia-rain-exp-2024-11-18-18-39-24]
# 13  [australia-rain-exp-2024-11-18-18-39-24]
# 14  [australia-rain-exp-2024-11-18-18-39-24]
# 15  [australia-rain-exp-2024-11-18-18-39-24]
# 16  [australia-rain-exp-2024-11-18-18-39-24]
#
#                                           DisplayName  train:auc - Min  \
# 0                                         xgboost-hpo              NaN
# 1                                         xgboost-hpo              NaN
# 2                                         xgboost-hpo              NaN
# 3                                         xgboost-hpo              NaN
# 4                                         xgboost-hpo              NaN
# 5                                         xgboost-hpo              NaN
# 6                                         xgboost-hpo              NaN
# 7                                         xgboost-hpo              NaN
# 8                                         xgboost-hpo              NaN
# 9                                    xgboost-training              NaN
# 10  australia-rain-processed-sm-xgb-2024-11-18-19-...         0.802526
# 11  australia-rain-processed-sm-xgb-2024-11-18-19-...              NaN
# 12                                   xgboost-training              NaN
# 13  australia-rain-processed-sm-xgb-2024-11-18-19-...              NaN
# 14                                   xgboost-training              NaN
# 15  australia-rain-processed-sm-xgb-2024-11-18-18-...              NaN
# 16                                   xgboost-training              NaN
#
#     train:auc - Max  train:auc - Avg  train:auc - StdDev  train:auc - Last  \
# 0               NaN              NaN                 NaN               NaN
# 1               NaN              NaN                 NaN               NaN
# 2               NaN              NaN                 NaN               NaN
# 3               NaN              NaN                 NaN               NaN
# 4               NaN              NaN                 NaN               NaN
# 5               NaN              NaN                 NaN               NaN
# 6               NaN              NaN                 NaN               NaN
# 7               NaN              NaN                 NaN               NaN
# 8               NaN              NaN                 NaN               NaN
# 9               NaN              NaN                 NaN               NaN
# 10         0.841825         0.831357             0.01255          0.841825
# 11              NaN              NaN                 NaN               NaN
# 12              NaN              NaN                 NaN               NaN
# 13              NaN              NaN                 NaN               NaN
# 14              NaN              NaN                 NaN               NaN
# 15              NaN              NaN                 NaN               NaN
# 16              NaN              NaN                 NaN               NaN
#
#     train:auc - Count validation - MediaType  \
# 0                 NaN                    NaN
# 1                 NaN                    NaN
# 2                 NaN                    NaN
# 3                 NaN                    NaN
# 4                 NaN                    NaN
# 5                 NaN                    NaN
# 6                 NaN                    NaN
# 7                 NaN                    NaN
# 8                 NaN                    NaN
# 9                 NaN                    NaN
# 10               10.0               text/csv
# 11                NaN                    NaN
# 12                NaN                    NaN
# 13                NaN                    NaN
# 14                NaN                    NaN
# 15                NaN               text/csv
# 16                NaN                    NaN
#
#                                    validation - Value val - MediaType  \
# 0                                                 NaN             NaN
# 1                                                 NaN             NaN
# 2                                                 NaN             NaN
# 3                                                 NaN             NaN
# 4                                                 NaN             NaN
# 5                                                 NaN             NaN
# 6                                                 NaN             NaN
# 7                                                 NaN             NaN
# 8                                                 NaN             NaN
# 9                                                 NaN             NaN
# 10  s3://sagemaker-us-east-1-335415446667/australi...             NaN
# 11                                                NaN        text/csv
# 12                                                NaN             NaN
# 13                                                NaN        text/csv
# 14                                                NaN             NaN
# 15  s3://sagemaker-us-east-1-335415446667/australi...             NaN
# 16                                                NaN             NaN
#
#                                           val - Value
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  s3://sagemaker-us-east-1-335415446667/australi...
# 12                                                NaN
# 13  s3://sagemaker-us-east-1-335415446667/australi...
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
